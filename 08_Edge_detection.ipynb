# %% [markdown]
# # Edge detection using the Canny alogorithm

# %%
# imports
import skimage as ski
import matplotlib.pyplot as plt
import numpy as np
from im_func import show_image, show_multi_image
import seaborn as sns
from skimage import transform

# %%
# Load stock image using function
title = 'camera'
title = 'coffee'
image = getattr(ski.data, title)()

show_image(image, title)

# %%
import skimage.feature
image_gray = ski.color.rgb2gray(image)
image_edge = ski.feature.canny(image_gray)
show_image(image_edge)
